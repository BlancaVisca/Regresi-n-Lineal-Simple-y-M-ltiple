# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('Datos_limpios.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21528 entries, 0 to 21527
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   21528 non-null  int64
#  1   last_scraped                 21528 non-null  object
#  2   name                         21528 non-null  object
#  3   description                  21528 non-null  object
#  4   neighborhood_overview        21528 non-null  object
#  5   host_location                21528 non-null  object
#  6   host_response_time           21528 non-null  object
#  7   host_is_superhost            21528 non-null  object
#  8   host_verifications           21528 non-null  object
#  9   host_has_profile_pic         21528 non-null  object
#  10  host_identity_verified       21528 non-null  object
#  11  neighbourhood                21528 non-null  object
#  12  property_type                21528 non-null  object
#  13  room_type                    21528 non-null  object
#  14  bathrooms_text               21528 non-null  object
#  15  amenities                    21528 non-null  object
#  16  price                        21528 non-null  object
#  17  has_availability             21528 non-null  object
#  18  last_review                  21528 non-null  object
#  19  instant_bookable             21528 non-null  object
#  20  host_response_rate           21528 non-null  float64
#  21  host_acceptance_rate         21528 non-null  float64
#  22  latitude                     21528 non-null  float64
#  23  longitude                    21528 non-null  float64
#  24  accommodates                 21528 non-null  float64
#  25  bathrooms                    21528 non-null  float64
#  26  bedrooms                     21528 non-null  float64
#  27  beds                         21528 non-null  float64
#  28  minimum_nights               21528 non-null  float64
#  29  maximum_nights               21528 non-null  float64
#  30  minimum_minimum_nights       21528 non-null  float64
#  31  maximum_minimum_nights       21528 non-null  float64
#  32  minimum_maximum_nights       21528 non-null  int64
#  33  maximum_maximum_nights       21528 non-null  int64
#  34  minimum_nights_avg_ntm       21528 non-null  float64
#  35  maximum_nights_avg_ntm       21528 non-null  float64
#  36  availability_30              21528 non-null  float64
#  37  availability_60              21528 non-null  float64
#  38  availability_90              21528 non-null  float64
#  39  availability_365             21528 non-null  int64
#  40  number_of_reviews            21528 non-null  float64
#  41  number_of_reviews_ltm        21528 non-null  float64
#  42  number_of_reviews_l30d       21528 non-null  float64
#  43  review_scores_rating         21528 non-null  float64
#  44  review_scores_cleanliness    21528 non-null  float64
#  45  review_scores_checkin        21528 non-null  float64
#  46  review_scores_communication  21528 non-null  float64
#  47  review_scores_location       21528 non-null  float64
#  48  review_scores_value          21528 non-null  float64
#  49  reviews_per_month            21528 non-null  float64
# dtypes: float64(27), int64(4), object(19)
# memory usage: 8.2+ MB

# %%
columnas_a_conservar = [
    "price", "room_type", "review_scores_cleanliness", "host_acceptance_rate",
    "host_identity_verified", "host_is_superhost", "instant_bookable",
    "accommodates", "bathrooms", "property_type"
]

# Filtrar DataFrame para mantener solo esas columnas
df = df[columnas_a_conservar]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21528 entries, 0 to 21527
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   price                      21528 non-null  object
#  1   room_type                  21528 non-null  object
#  2   review_scores_cleanliness  21528 non-null  float64
#  3   host_acceptance_rate       21528 non-null  float64
#  4   host_identity_verified     21528 non-null  object
#  5   host_is_superhost          21528 non-null  object
#  6   instant_bookable           21528 non-null  object
#  7   accommodates               21528 non-null  float64
#  8   bathrooms                  21528 non-null  float64
#  9   property_type              21528 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1.6+ MB

# %%
df=df
df['room_type'] = df['room_type'].map({
    'Entire home/apt': 1,
    'Private room': 2,
    'Shared room': 3,
    'Hotel room': 4
})

# %%
import re
df['price']= df['price'].apply(lambda x: float(re.sub(r'[^0-9.]', '', x)) if re.search(r'\d', x) else None)

# %%
sorted_values = df['price'].sort_values(ascending=True)
sorted_values
# Out:
# 11505       100.0
# 12190       100.0
# 12191       100.0
# 8630        100.0
# 12195       100.0
#            ...
# 15431     39899.0
# 7187      41800.0
# 5305      62000.0
# 19948     74580.0
# 12962    100000.0
# Name: price, Length: 21528, dtype: float64

# %%
df = df[df['price'] <40000]

# %%
df1 = df[df["room_type"] ==1]

# %%
Y= df1['price']
X1= df1['room_type'].to_frame()

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.fit(X=X1, y=Y)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['room_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(904.6701845620476)}

# %%
y_pred= model.predict(X=X1)
y_pred
# Out:
# array([904.67018456, 904.67018456, 904.67018456, ..., 904.67018456,
#        904.67018456, 904.67018456], shape=(19614,))

# %%
sns.scatterplot(x='room_type', y='price', color="blue", data=df1)
sns.scatterplot(x='room_type', y=y_pred, color="red", data=df1)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
coef_Deter= model.score(X=X1, y=Y)
coef_Deter
# Out:
# 0.0

# %%
coef_Correl= np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19614 entries, 0 to 21527
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   price                      19614 non-null  float64
#  1   room_type                  19614 non-null  int64
#  2   review_scores_cleanliness  19614 non-null  float64
#  3   host_acceptance_rate       19614 non-null  float64
#  4   host_identity_verified     19614 non-null  object
#  5   host_is_superhost          19614 non-null  object
#  6   instant_bookable           19614 non-null  object
#  7   accommodates               19614 non-null  float64
#  8   bathrooms                  19614 non-null  float64
#  9   property_type              19614 non-null  object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 1.6+ MB

# %%
Y2= df1['price']
X2= df1['host_acceptance_rate'].to_frame()

# %%
from sklearn.linear_model import LinearRegression
model2= LinearRegression()
type(model2)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model2.fit(X=X2, y=Y2)
# Out:
# LinearRegression()

# %%
model2.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_acceptance_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-1.75827431]),
#  'rank_': 1,
#  'singular_': array([4093.79054142]),
#  'intercept_': np.float64(1022.1479009345877)}

# %%
y_pred2= model2.predict(X=X2)
y_pred2
# Out:
# array([846.32047029, 904.3435224 , 846.32047029, ..., 904.3435224 ,
#        904.3435224 , 904.3435224 ], shape=(19614,))

# %%
sns.scatterplot(x='host_acceptance_rate', y='price', color="blue", data=df1)
sns.scatterplot(x='host_acceptance_rate', y=y_pred2, color="red", data=df1)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
coef_Deter2= model2.score(X=X2, y=Y2)
coef_Deter2
# Out:
# 0.0030508702760840833

# %%
coef_Correl2= np.sqrt(coef_Deter2)
coef_Correl2
# Out:
# np.float64(0.055234683633420795)

# %%
df1['host_is_superhost'] = df1['host_is_superhost'].replace({'f': 0, 't': 1})
# Out:
# C:\Users\blanf\AppData\Local\Temp\ipykernel_33396\4038004741.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1['host_is_superhost'] = df1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\blanf\AppData\Local\Temp\ipykernel_33396\4038004741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['host_is_superhost'] = df1['host_is_superhost'].replace({'f': 0, 't': 1})

# %%
Y3= df1['price']
X3= df1['host_is_superhost'].to_frame()

# %%
from sklearn.linear_model import LinearRegression
model3= LinearRegression()
type(model3)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model3.fit(X=X3, y=Y3)
# Out:
# LinearRegression()

# %%
y_pred3= model3.predict(X=X3)
y_pred3
# Out:
# array([ 873.20143967,  873.20143967, 1165.72654028, ...,  873.20143967,
#         873.20143967,  873.20143967], shape=(19614,))

# %%
sns.scatterplot(x='host_is_superhost', y='price', color="blue", data=df1)
sns.scatterplot(x='host_is_superhost', y=y_pred3, color="red", data=df1)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
coef_Deter3= model3.score(X=X3, y=Y3)
coef_Deter3
# Out:
# 0.009488096855029382

# %%
coef_Correl3= np.sqrt(coef_Deter3)
coef_Correl3
# Out:
# np.float64(0.09740686246373703)

# %%
Y4= df1['accommodates']
X4= df1['bathrooms'].to_frame()

# %%
from sklearn.linear_model import LinearRegression
model4= LinearRegression()
type(model4)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model4.fit(X=X4, y=Y4)
# Out:
# LinearRegression()

# %%
y_pred4= model4.predict(X=X4)
y_pred4
# Out:
# array([3.31786043, 3.31786043, 3.31786043, ..., 3.31786043, 3.31786043,
#        3.31786043], shape=(19614,))

# %%
sns.scatterplot(x='bathrooms', y='accommodates', color="blue", data=df1)
sns.scatterplot(x='bathrooms', y=y_pred4, color="red", data=df1)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
coef_Deter4= model4.score(X=X4, y=Y4)
coef_Deter4
# Out:
# 0.0005706567683191333

# %%
coef_Correl4= np.sqrt(coef_Deter4)
coef_Correl4
# Out:
# np.float64(0.023888423311703374)

# %%
Y5= df1['price']
X5= df1['review_scores_cleanliness'].to_frame()

# %%
from sklearn.linear_model import LinearRegression
model5= LinearRegression()
type(model5)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model5.fit(X=X5, y=Y5)
# Out:
# LinearRegression()

# %%
y_pred5= model5.predict(X=X5)
y_pred5
# Out:
# array([918.99578507, 916.07714769, 919.72544442, ..., 911.69919162,
#        911.69919162, 911.69919162], shape=(19614,))

# %%
sns.scatterplot(x='review_scores_cleanliness', y='price', color="blue", data=df1)
sns.scatterplot(x='review_scores_cleanliness', y=y_pred5, color="red", data=df1)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
coef_Deter5= model5.score(X=X5, y=Y5)
coef_Deter5
# Out:
# 0.0007542672646376758

# %%
coef_Correl5= np.sqrt(coef_Deter5)
coef_Correl5
# Out:
# np.float64(0.027463926606326267)

# %%
df1['host_identity_verified'] = df1['host_identity_verified'].replace({'f': 0, 't': 1})
# Out:
# C:\Users\blanf\AppData\Local\Temp\ipykernel_33396\3355181784.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1['host_identity_verified'] = df1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\blanf\AppData\Local\Temp\ipykernel_33396\3355181784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['host_identity_verified'] = df1['host_identity_verified'].replace({'f': 0, 't': 1})

# %%
Y6= df1['price']
X6= df1['host_identity_verified'].to_frame()

# %%
from sklearn.linear_model import LinearRegression
model6= LinearRegression()
type(model6)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model6.fit(X=X6, y=Y6)
# Out:
# LinearRegression()

# %%
y_pred6= model6.predict(X=X6)
y_pred6
# Out:
# array([919.85967854, 919.85967854, 919.85967854, ..., 791.33218292,
#        919.85967854, 919.85967854], shape=(19614,))

# %%
sns.scatterplot(x='host_identity_verified', y='price', color="blue", data=df1)
sns.scatterplot(x='host_identity_verified', y=y_pred6, color="red", data=df1)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
coef_Deter6= model6.score(X=X6, y=Y6)
coef_Deter6
# Out:
# 0.0019883108091848234

# %%
coef_Correl6= np.sqrt(coef_Deter6)
coef_Correl6
# Out:
# np.float64(0.044590478907327556)

# %%
df1['instant_bookable'] = df1['instant_bookable'].replace({'f': 0, 't': 1})
# Out:
# C:\Users\blanf\AppData\Local\Temp\ipykernel_33396\1876949163.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1['instant_bookable'] = df1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\blanf\AppData\Local\Temp\ipykernel_33396\1876949163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['instant_bookable'] = df1['instant_bookable'].replace({'f': 0, 't': 1})

# %%
Y7= df1['price']
X7= df1['instant_bookable'].to_frame()

# %%
from sklearn.linear_model import LinearRegression
model7= LinearRegression()
type(model7)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model7.fit(X=X7, y=Y7)
# Out:
# LinearRegression()

# %%
y_pred7= model7.predict(X=X7)
y_pred7
# Out:
# array([897.13951932, 897.13951932, 897.13951932, ..., 897.13951932,
#        985.00773349, 897.13951932], shape=(19614,))

# %%
sns.scatterplot(x='instant_bookable', y='price', color="blue", data=df1)
sns.scatterplot(x='instant_bookable', y=y_pred7, color="red", data=df1)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
coef_Deter7= model7.score(X=X7, y=Y7)
coef_Deter7
# Out:
# 0.0006987427847078287

# %%
coef_Correl7= np.sqrt(coef_Deter7)
coef_Correl7
# Out:
# np.float64(0.02643374329730522)

# %%
df1['property_type'] = df1['property_type'].replace({
    'Entire rental unit': 1,
    'Entire condo': 2,
    'Private room in rental unit': 3,
    'Entire home': 4,
    'Private room in condo': 5,
    'Entire townhouse': 6,
    'Private room in home': 7,
    'Entire villa': 8,
    'Entire loft': 9,
    'Private room in villa': 10,
    'Entire serviced apartment': 11,
    'Private room in townhouse': 12,
    'Room in hotel': 13,
    'Entire guesthouse': 14,
    'Private room in bed and breakfast': 15,
    'Room in aparthotel': 16,
    'Private room in guest suite': 17,
    'Private room in casa particular': 18,
    'Shared room in hotel': 19,
    'Private room in guesthouse': 20,
    'Tiny home': 21,
    'Shared room in hostel': 22,
    'Private room in serviced apartment': 23,
    'Private room in boat': 24,
    'Houseboat': 25,
    'Entire guest suite': 26,
    'Boat': 27,
    'Shared room in rental unit': 28,
    'Shared room in condo': 29,
    'Private room in loft': 30,
    'Private room': 31,
    'Private room in bungalow': 32,
    'Private room in hostel': 33,
    'Entire bungalow': 34,
    'Entire vacation home': 35,
    'Entire cabin': 36,
    'Private room in shipping container': 37,
    'Room in hostel': 38,
    'Camper/RV': 39,
    'Entire place': 40,
    'Barn': 41,
    'Casa particular': 42,
    'Entire cottage': 43,
    'Private room in hut': 44,
    'Shared room in bungalow': 45,
    'Private room in tiny home': 46,
    'Shared room in bed and breakfast': 47,
    'Private room in vacation home': 48,
    'Hut': 49,
    'Private room in barn': 50,
    'Minsu': 51,
    'Shipping container': 52,
    'Private room in cabin': 53,
    'Tower': 54,
    'Dome': 55,
    'Farm stay': 56,
     'Tent': 57

})
# Out:
# C:\Users\blanf\AppData\Local\Temp\ipykernel_33396\2162765534.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1['property_type'] = df1['property_type'].replace({
# C:\Users\blanf\AppData\Local\Temp\ipykernel_33396\2162765534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['property_type'] = df1['property_type'].replace({

# %%
Y8= df1['price']
X8= df1['property_type'].to_frame()

# %%
df1['property_type'] = df1['property_type'].replace({...}).astype(float)
# Out:
# C:\Users\blanf\AppData\Local\Temp\ipykernel_33396\1373559198.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df1['property_type'] = df1['property_type'].replace({...}).astype(float)
# C:\Users\blanf\AppData\Local\Temp\ipykernel_33396\1373559198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['property_type'] = df1['property_type'].replace({...}).astype(float)

# %%
from sklearn.linear_model import LinearRegression
model8= LinearRegression()
type(model8)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model8.fit(X=X8, y=Y8)
# Out:
# LinearRegression()

# %%
y_pred8= model8.predict(X=X8)
y_pred8
# Out:
# array([908.22637627, 908.22637627, 877.30831595, ..., 877.30831595,
#        877.30831595, 877.30831595], shape=(19614,))

# %%
sns.scatterplot(x='property_type', y='price', color="blue", data=df1)
sns.scatterplot(x='property_type', y=y_pred8, color="red", data=df1)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
coef_Deter8= model8.score(X=X8, y=Y8)
coef_Deter8
# Out:
# 0.007997573658889534

# %%
coef_Correl8= np.sqrt(coef_Deter8)
coef_Correl8
# Out:
# np.float64(0.0894291544122471)

# %%
df1 = df1.drop('room_type', axis=1)

# %%
Corr_Factors=df1.corr()
Corr_Factors
# Out:
#                                       Predicción_Host_acceptance_rate  \
# Predicción_Host_acceptance_rate                              1.000000
# Predicción_Host_is_superhost                                -0.212649
# Predicción_accommodates                                     -0.024917
# Predicción_review_scores_cleanliness                        -0.027478
# Predicción_host_identity_verified                           -0.050854
# Predicción_instant_bookable                                 -0.239248
# Predicción_property_type                                    -0.039686
# price                                                        0.055235
# review_scores_cleanliness                                   -0.027478
# host_acceptance_rate                                        -1.000000
# host_identity_verified                                      -0.050854
# host_is_superhost                                           -0.212649
# instant_bookable                                            -0.239248
# accommodates                                                -0.027937
# bathrooms                                                   -0.024917
# property_type                                               -0.039686
#
#                                       Predicción_Host_is_superhost  \
# Predicción_Host_acceptance_rate                          -0.212649
# Predicción_Host_is_superhost                              1.000000
# Predicción_accommodates                                   0.003181
# Predicción_review_scores_cleanliness                      0.072268
# Predicción_host_identity_verified                         0.085816
# Predicción_instant_bookable                               0.047122
# Predicción_property_type                                  0.032812
# price                                                     0.097407
# review_scores_cleanliness                                 0.072268
# host_acceptance_rate                                      0.212649
# host_identity_verified                                    0.085816
# host_is_superhost                                         1.000000
# instant_bookable                                          0.047122
# accommodates                                             -0.003610
# bathrooms                                                 0.003181
# property_type                                             0.032812
#
#                                       Predicción_accommodates  \
# Predicción_Host_acceptance_rate                     -0.024917
# Predicción_Host_is_superhost                         0.003181
# Predicción_accommodates                              1.000000
# Predicción_review_scores_cleanliness                 0.001150
# Predicción_host_identity_verified                    0.010905
# Predicción_instant_bookable                          0.015280
# Predicción_property_type                            -0.010705
# price                                               -0.026858
# review_scores_cleanliness                            0.001150
# host_acceptance_rate                                 0.024917
# host_identity_verified                               0.010905
# host_is_superhost                                    0.003181
# instant_bookable                                     0.015280
# accommodates                                         0.023888
# bathrooms                                            1.000000
# property_type                                       -0.010705
#
#                                       Predicción_review_scores_cleanliness  \
# Predicción_Host_acceptance_rate                                  -0.027478
# Predicción_Host_is_superhost                                      0.072268
# Predicción_accommodates                                           0.001150
# Predicción_review_scores_cleanliness                              1.000000
# Predicción_host_identity_verified                                 0.011445
# Predicción_instant_bookable                                      -0.054757
# Predicción_property_type                                         -0.011998
# price                                                             0.027464
# review_scores_cleanliness                                         1.000000
# host_acceptance_rate                                              0.027478
# host_identity_verified                                            0.011445
# host_is_superhost                                                 0.072268
# instant_bookable                                                 -0.054757
# accommodates                                                     -0.015398
# bathrooms                                                         0.001150
# property_type                                                    -0.011998
#
#                                       Predicción_host_identity_verified  \
# Predicción_Host_acceptance_rate                               -0.050854
# Predicción_Host_is_superhost                                   0.085816
# Predicción_accommodates                                        0.010905
# Predicción_review_scores_cleanliness                           0.011445
# Predicción_host_identity_verified                              1.000000
# Predicción_instant_bookable                                   -0.019937
# Predicción_property_type                                       0.020208
# price                                                          0.044590
# review_scores_cleanliness                                      0.011445
# host_acceptance_rate                                           0.050854
# host_identity_verified                                         1.000000
# host_is_superhost                                              0.085816
# instant_bookable                                              -0.019937
# accommodates                                                   0.037553
# bathrooms                                                      0.010905
# property_type                                                  0.020208
#
#                                       Predicción_instant_bookable  \
# Predicción_Host_acceptance_rate                         -0.239248
# Predicción_Host_is_superhost                             0.047122
# Predicción_accommodates                                  0.015280
# Predicción_review_scores_cleanliness                    -0.054757
# Predicción_host_identity_verified                       -0.019937
# Predicción_instant_bookable                              1.000000
# Predicción_property_type                                 0.045499
# price                                                    0.026434
# review_scores_cleanliness                               -0.054757
# host_acceptance_rate                                     0.239248
# host_identity_verified                                  -0.019937
# host_is_superhost                                        0.047122
# instant_bookable                                         1.000000
# accommodates                                             0.030204
# bathrooms                                                0.015280
# property_type                                            0.045499
#
#                                       Predicción_property_type     price  \
# Predicción_Host_acceptance_rate                      -0.039686  0.055235
# Predicción_Host_is_superhost                          0.032812  0.097407
# Predicción_accommodates                              -0.010705 -0.026858
# Predicción_review_scores_cleanliness                 -0.011998  0.027464
# Predicción_host_identity_verified                     0.020208  0.044590
# Predicción_instant_bookable                           0.045499  0.026434
# Predicción_property_type                              1.000000  0.089429
# price                                                 0.089429  1.000000
# review_scores_cleanliness                            -0.011998  0.027464
# host_acceptance_rate                                  0.039686 -0.055235
# host_identity_verified                                0.020208  0.044590
# host_is_superhost                                     0.032812  0.097407
# instant_bookable                                      0.045499  0.026434
# accommodates                                          0.151749  0.220200
# bathrooms                                            -0.010705 -0.026858
# property_type                                         1.000000  0.089429
#
#                                       review_scores_cleanliness  \
# Predicción_Host_acceptance_rate                       -0.027478
# Predicción_Host_is_superhost                           0.072268
# Predicción_accommodates                                0.001150
# Predicción_review_scores_cleanliness                   1.000000
# Predicción_host_identity_verified                      0.011445
# Predicción_instant_bookable                           -0.054757
# Predicción_property_type                              -0.011998
# price                                                  0.027464
# review_scores_cleanliness                              1.000000
# host_acceptance_rate                                   0.027478
# host_identity_verified                                 0.011445
# host_is_superhost                                      0.072268
# instant_bookable                                      -0.054757
# accommodates                                          -0.015398
# bathrooms                                              0.001150
# property_type                                         -0.011998
#
#                                       host_acceptance_rate  \
# Predicción_Host_acceptance_rate                  -1.000000
# Predicción_Host_is_superhost                      0.212649
# Predicción_accommodates                           0.024917
# Predicción_review_scores_cleanliness              0.027478
# Predicción_host_identity_verified                 0.050854
# Predicción_instant_bookable                       0.239248
# Predicción_property_type                          0.039686
# price                                            -0.055235
# review_scores_cleanliness                         0.027478
# host_acceptance_rate                              1.000000
# host_identity_verified                            0.050854
# host_is_superhost                                 0.212649
# instant_bookable                                  0.239248
# accommodates                                      0.027937
# bathrooms                                         0.024917
# property_type                                     0.039686
#
#                                       host_identity_verified  \
# Predicción_Host_acceptance_rate                    -0.050854
# Predicción_Host_is_superhost                        0.085816
# Predicción_accommodates                             0.010905
# Predicción_review_scores_cleanliness                0.011445
# Predicción_host_identity_verified                   1.000000
# Predicción_instant_bookable                        -0.019937
# Predicción_property_type                            0.020208
# price                                               0.044590
# review_scores_cleanliness                           0.011445
# host_acceptance_rate                                0.050854
# host_identity_verified                              1.000000
# host_is_superhost                                   0.085816
# instant_bookable                                   -0.019937
# accommodates                                        0.037553
# bathrooms                                           0.010905
# property_type                                       0.020208
#
#                                       host_is_superhost  instant_bookable  \
# Predicción_Host_acceptance_rate               -0.212649         -0.239248
# Predicción_Host_is_superhost                   1.000000          0.047122
# Predicción_accommodates                        0.003181          0.015280
# Predicción_review_scores_cleanliness           0.072268         -0.054757
# Predicción_host_identity_verified              0.085816         -0.019937
# Predicción_instant_bookable                    0.047122          1.000000
# Predicción_property_type                       0.032812          0.045499
# price                                          0.097407          0.026434
# review_scores_cleanliness                      0.072268         -0.054757
# host_acceptance_rate                           0.212649          0.239248
# host_identity_verified                         0.085816         -0.019937
# host_is_superhost                              1.000000          0.047122
# instant_bookable                               0.047122          1.000000
# accommodates                                  -0.003610          0.030204
# bathrooms                                      0.003181          0.015280
# property_type                                  0.032812          0.045499
#
#                                       accommodates  bathrooms  property_type
# Predicción_Host_acceptance_rate          -0.027937  -0.024917      -0.039686
# Predicción_Host_is_superhost             -0.003610   0.003181       0.032812
# Predicción_accommodates                   0.023888   1.000000      -0.010705
# Predicción_review_scores_cleanliness     -0.015398   0.001150      -0.011998
# Predicción_host_identity_verified         0.037553   0.010905       0.020208
# Predicción_instant_bookable               0.030204   0.015280       0.045499
# Predicción_property_type                  0.151749  -0.010705       1.000000
# price                                     0.220200  -0.026858       0.089429
# review_scores_cleanliness                -0.015398   0.001150      -0.011998
# host_acceptance_rate                      0.027937   0.024917       0.039686
# host_identity_verified                    0.037553   0.010905       0.020208
# host_is_superhost                        -0.003610   0.003181       0.032812
# instant_bookable                          0.030204   0.015280       0.045499
# accommodates                              1.000000   0.023888       0.151749
# bathrooms                                 0.023888   1.000000      -0.010705
# property_type                             0.151749  -0.010705       1.000000

# %%
df1.insert(0, 'Predicción_Host_acceptance_rate', y_pred2)
df1.insert(1, 'Predicción_Host_is_superhost', y_pred3)
df1.insert(2, 'Predicción_accommodates', y_pred4)
df1.insert(3, 'Predicción_review_scores_cleanliness', y_pred5)
df1.insert(4, 'Predicción_host_identity_verified', y_pred6)
df1.insert(5, 'Predicción_instant_bookable', y_pred7)
df1.insert(6, 'Predicción_property_type', y_pred8)

# %%
#Convierte todo a positivo :(
Corr_Factors1=abs(Corr_Factors)
Corr_Factors1
# Out:
#                                       Predicción_Host_acceptance_rate  \
# Predicción_Host_acceptance_rate                              1.000000
# Predicción_Host_is_superhost                                 0.212649
# Predicción_accommodates                                      0.024917
# Predicción_review_scores_cleanliness                         0.027478
# Predicción_host_identity_verified                            0.050854
# Predicción_instant_bookable                                  0.239248
# Predicción_property_type                                     0.039686
# price                                                        0.055235
# review_scores_cleanliness                                    0.027478
# host_acceptance_rate                                         1.000000
# host_identity_verified                                       0.050854
# host_is_superhost                                            0.212649
# instant_bookable                                             0.239248
# accommodates                                                 0.027937
# bathrooms                                                    0.024917
# property_type                                                0.039686
#
#                                       Predicción_Host_is_superhost  \
# Predicción_Host_acceptance_rate                           0.212649
# Predicción_Host_is_superhost                              1.000000
# Predicción_accommodates                                   0.003181
# Predicción_review_scores_cleanliness                      0.072268
# Predicción_host_identity_verified                         0.085816
# Predicción_instant_bookable                               0.047122
# Predicción_property_type                                  0.032812
# price                                                     0.097407
# review_scores_cleanliness                                 0.072268
# host_acceptance_rate                                      0.212649
# host_identity_verified                                    0.085816
# host_is_superhost                                         1.000000
# instant_bookable                                          0.047122
# accommodates                                              0.003610
# bathrooms                                                 0.003181
# property_type                                             0.032812
#
#                                       Predicción_accommodates  \
# Predicción_Host_acceptance_rate                      0.024917
# Predicción_Host_is_superhost                         0.003181
# Predicción_accommodates                              1.000000
# Predicción_review_scores_cleanliness                 0.001150
# Predicción_host_identity_verified                    0.010905
# Predicción_instant_bookable                          0.015280
# Predicción_property_type                             0.010705
# price                                                0.026858
# review_scores_cleanliness                            0.001150
# host_acceptance_rate                                 0.024917
# host_identity_verified                               0.010905
# host_is_superhost                                    0.003181
# instant_bookable                                     0.015280
# accommodates                                         0.023888
# bathrooms                                            1.000000
# property_type                                        0.010705
#
#                                       Predicción_review_scores_cleanliness  \
# Predicción_Host_acceptance_rate                                   0.027478
# Predicción_Host_is_superhost                                      0.072268
# Predicción_accommodates                                           0.001150
# Predicción_review_scores_cleanliness                              1.000000
# Predicción_host_identity_verified                                 0.011445
# Predicción_instant_bookable                                       0.054757
# Predicción_property_type                                          0.011998
# price                                                             0.027464
# review_scores_cleanliness                                         1.000000
# host_acceptance_rate                                              0.027478
# host_identity_verified                                            0.011445
# host_is_superhost                                                 0.072268
# instant_bookable                                                  0.054757
# accommodates                                                      0.015398
# bathrooms                                                         0.001150
# property_type                                                     0.011998
#
#                                       Predicción_host_identity_verified  \
# Predicción_Host_acceptance_rate                                0.050854
# Predicción_Host_is_superhost                                   0.085816
# Predicción_accommodates                                        0.010905
# Predicción_review_scores_cleanliness                           0.011445
# Predicción_host_identity_verified                              1.000000
# Predicción_instant_bookable                                    0.019937
# Predicción_property_type                                       0.020208
# price                                                          0.044590
# review_scores_cleanliness                                      0.011445
# host_acceptance_rate                                           0.050854
# host_identity_verified                                         1.000000
# host_is_superhost                                              0.085816
# instant_bookable                                               0.019937
# accommodates                                                   0.037553
# bathrooms                                                      0.010905
# property_type                                                  0.020208
#
#                                       Predicción_instant_bookable  \
# Predicción_Host_acceptance_rate                          0.239248
# Predicción_Host_is_superhost                             0.047122
# Predicción_accommodates                                  0.015280
# Predicción_review_scores_cleanliness                     0.054757
# Predicción_host_identity_verified                        0.019937
# Predicción_instant_bookable                              1.000000
# Predicción_property_type                                 0.045499
# price                                                    0.026434
# review_scores_cleanliness                                0.054757
# host_acceptance_rate                                     0.239248
# host_identity_verified                                   0.019937
# host_is_superhost                                        0.047122
# instant_bookable                                         1.000000
# accommodates                                             0.030204
# bathrooms                                                0.015280
# property_type                                            0.045499
#
#                                       Predicción_property_type     price  \
# Predicción_Host_acceptance_rate                       0.039686  0.055235
# Predicción_Host_is_superhost                          0.032812  0.097407
# Predicción_accommodates                               0.010705  0.026858
# Predicción_review_scores_cleanliness                  0.011998  0.027464
# Predicción_host_identity_verified                     0.020208  0.044590
# Predicción_instant_bookable                           0.045499  0.026434
# Predicción_property_type                              1.000000  0.089429
# price                                                 0.089429  1.000000
# review_scores_cleanliness                             0.011998  0.027464
# host_acceptance_rate                                  0.039686  0.055235
# host_identity_verified                                0.020208  0.044590
# host_is_superhost                                     0.032812  0.097407
# instant_bookable                                      0.045499  0.026434
# accommodates                                          0.151749  0.220200
# bathrooms                                             0.010705  0.026858
# property_type                                         1.000000  0.089429
#
#                                       review_scores_cleanliness  \
# Predicción_Host_acceptance_rate                        0.027478
# Predicción_Host_is_superhost                           0.072268
# Predicción_accommodates                                0.001150
# Predicción_review_scores_cleanliness                   1.000000
# Predicción_host_identity_verified                      0.011445
# Predicción_instant_bookable                            0.054757
# Predicción_property_type                               0.011998
# price                                                  0.027464
# review_scores_cleanliness                              1.000000
# host_acceptance_rate                                   0.027478
# host_identity_verified                                 0.011445
# host_is_superhost                                      0.072268
# instant_bookable                                       0.054757
# accommodates                                           0.015398
# bathrooms                                              0.001150
# property_type                                          0.011998
#
#                                       host_acceptance_rate  \
# Predicción_Host_acceptance_rate                   1.000000
# Predicción_Host_is_superhost                      0.212649
# Predicción_accommodates                           0.024917
# Predicción_review_scores_cleanliness              0.027478
# Predicción_host_identity_verified                 0.050854
# Predicción_instant_bookable                       0.239248
# Predicción_property_type                          0.039686
# price                                             0.055235
# review_scores_cleanliness                         0.027478
# host_acceptance_rate                              1.000000
# host_identity_verified                            0.050854
# host_is_superhost                                 0.212649
# instant_bookable                                  0.239248
# accommodates                                      0.027937
# bathrooms                                         0.024917
# property_type                                     0.039686
#
#                                       host_identity_verified  \
# Predicción_Host_acceptance_rate                     0.050854
# Predicción_Host_is_superhost                        0.085816
# Predicción_accommodates                             0.010905
# Predicción_review_scores_cleanliness                0.011445
# Predicción_host_identity_verified                   1.000000
# Predicción_instant_bookable                         0.019937
# Predicción_property_type                            0.020208
# price                                               0.044590
# review_scores_cleanliness                           0.011445
# host_acceptance_rate                                0.050854
# host_identity_verified                              1.000000
# host_is_superhost                                   0.085816
# instant_bookable                                    0.019937
# accommodates                                        0.037553
# bathrooms                                           0.010905
# property_type                                       0.020208
#
#                                       host_is_superhost  instant_bookable  \
# Predicción_Host_acceptance_rate                0.212649          0.239248
# Predicción_Host_is_superhost                   1.000000          0.047122
# Predicción_accommodates                        0.003181          0.015280
# Predicción_review_scores_cleanliness           0.072268          0.054757
# Predicción_host_identity_verified              0.085816          0.019937
# Predicción_instant_bookable                    0.047122          1.000000
# Predicción_property_type                       0.032812          0.045499
# price                                          0.097407          0.026434
# review_scores_cleanliness                      0.072268          0.054757
# host_acceptance_rate                           0.212649          0.239248
# host_identity_verified                         0.085816          0.019937
# host_is_superhost                              1.000000          0.047122
# instant_bookable                               0.047122          1.000000
# accommodates                                   0.003610          0.030204
# bathrooms                                      0.003181          0.015280
# property_type                                  0.032812          0.045499
#
#                                       accommodates  bathrooms  property_type
# Predicción_Host_acceptance_rate           0.027937   0.024917       0.039686
# Predicción_Host_is_superhost              0.003610   0.003181       0.032812
# Predicción_accommodates                   0.023888   1.000000       0.010705
# Predicción_review_scores_cleanliness      0.015398   0.001150       0.011998
# Predicción_host_identity_verified         0.037553   0.010905       0.020208
# Predicción_instant_bookable               0.030204   0.015280       0.045499
# Predicción_property_type                  0.151749   0.010705       1.000000
# price                                     0.220200   0.026858       0.089429
# review_scores_cleanliness                 0.015398   0.001150       0.011998
# host_acceptance_rate                      0.027937   0.024917       0.039686
# host_identity_verified                    0.037553   0.010905       0.020208
# host_is_superhost                         0.003610   0.003181       0.032812
# instant_bookable                          0.030204   0.015280       0.045499
# accommodates                              1.000000   0.023888       0.151749
# bathrooms                                 0.023888   1.000000       0.010705
# property_type                             0.151749   0.010705       1.000000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(Corr_Factors1, cmap='Blues', annot=True, fmt=".2f")
plt.title("Heatmap con Predicciones")
plt.show()
